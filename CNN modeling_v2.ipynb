# %%
# 얼굴.ipynb 파일을 이용해서
# 이광수와 웡위칭의 이미지를
# 네이버, 구글, 다음에서 크롤링해와 저장했다.

# %%
# 하지만, GIGO로 안 좋은 데이터가 들어가면 안 좋은 결과가 나오기 때문에
# 데이터 전처리 과정을 하기 전에
# 사람이 아닌 사진이거나, 이광수, 웡위칭이 없는 사진은 제거하도록 하자.

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install face-recognition
# Out:
# ...
#      |████████████████████████████████| 100.2MB 42kB/s
# ...
#   Created wheel for face-recognition-models: filename=face_recognition_models-0.3.0-py2.py3-none-any.whl size=100566173 sha256=1d415941ed15d11c2fdc21bc3e0990d641126c1ff53ebd5a7e26b0c7367742d6
#   Stored in directory: /root/.cache/pip/wheels/d2/99/18/59c6c8f01e39810415c0e63f5bede7d83dfb0ffc039865465f
# Successfully built face-recognition-models
# ...

# %%
# !pip install face_recognition

# %%
import face_recognition

# %%
# !unzip /content/drive/'My Drive'/GoogleColab/'Gwangsu-Yuqing-CNN_Study'/CNN_data/0.zip -d /content/drive/'My Drive'/GoogleColab/'Gwangsu-Yuqing-CNN_Study'/image/0
# !unzip /content/drive/'My Drive'/GoogleColab/'Gwangsu-Yuqing-CNN_Study'/CNN_data/1.zip -d /content/drive/'My Drive'/GoogleColab/'Gwangsu-Yuqing-CNN_Study'/image/1
# Out:
# Archive:  /content/drive/My Drive/GoogleColab/deep-learning/CNN_data/0.zip
# Daum_이광수 배우_0.png:  mismatching "local" filename (Daum_ьЭ┤ъ┤СьИШ ы░░ьЪ░_0.png),
#          continuing with "central" filename version
#   inflating: /content/drive/My Drive/GoogleColab/deep-learning/image/0/Daum_이광수 배우_0.png
# Daum_이광수 배우_1.png:  mismatching "local" filename (Daum_ьЭ┤ъ┤СьИШ ы░░ьЪ░_1.png),
#          continuing with "central" filename version
#   inflating: /content/drive/My Drive/GoogleColab/deep-learning/image/0/Daum_이광수 배우_1.png
# Daum_이광수 배우_10.png:  mismatching "local" filename (Daum_ьЭ┤ъ┤СьИШ ы░░ьЪ░_10.png),
#          continuing with "central" filename version
#   inflating: /content/drive/My Drive/GoogleColab/deep-learning/image/0/Daum_이광수 배우_10.png
# Daum_이광수 배우_106.png:  mismatching "local" filename (Daum_ьЭ┤ъ┤СьИШ ы░░ьЪ░_106.png),
#          continuing with "central" filename version
#   inflating: /content/drive/My Drive/GoogleColab/deep-learning/image/0/Daum_이광수 배우_106.png
# ...

# %%
import sys
import os
gs_img_dir = r'/content/sample_data/image/0'  # 이광수 사진 든 디렉토리 주소
wc_img_dir = r'/content/sample_data/image/1'  # 웡위칭 사진 든 디렉토리 주소

gs_img_list = os.listdir(gs_img_dir)
wc_img_list = os.listdir(wc_img_dir)
# type(os.listdir(gs_img_dir))
gs_img_list[0]
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-9-b7b092216e4f> in <module>()
#       4 wc_img_dir = r'/content/sample_data/image/1'  # 웡위칭 사진 든 디렉토리 주소
#       5
# ----> 6 gs_img_list = os.listdir(gs_img_dir)
#       7 wc_img_list = os.listdir(wc_img_dir)
#       8 # type(os.listdir(gs_img_dir))
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/sample_data/image/0'

# %%
# after_face_recog_gs_list = []
# after_face_recog_wc_list = []

# gs_img_list[0]
# type(gs_img_list[0])


# for i in range(len(gs_img_list)):
#   image_name = gs_img_dir[i]
#   print(image_name)
#   image = face_recognition.load_image_file(f"{gs_img_dir}/{image_name}.png")
#   print(image)

# %%
image = face_recognition.load_image_file(r'/content/sample_data/image/0/Daum_이광수 배우_0.png')
face_location = face_recognition.face_locations(image)

import matplotlib.pyplot as plt
# plt.imshow(image)
print(face_location)

# %%
print(image)

# %%
plt.imshow(image)

# %%
print(face_location)

# %%
from PIL import Image
for location in face_location:
  top, right, bottom, left = face_location

  face_image = image[top:bottom, left:right]
  pil_image = Image.fromarray(face_image)
  pil_image.show()
